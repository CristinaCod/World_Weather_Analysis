# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 768

# %%
cd ..
# Out:
# /Users/cristinacodispoti/Desktop/Bootcamp/World_Weather_Analysis

# %%
# Import the requests library.
import requests

# Import the API key.
from config1 import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8eda0f82b697d090d47d4b19ac1e59ef

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | clyde river
# Processing Record 2 of Set 1 | majenang
# Processing Record 3 of Set 1 | sataua
# City not found. Skipping...
# Processing Record 4 of Set 1 | bengkulu
# Processing Record 5 of Set 1 | bethel
# Processing Record 6 of Set 1 | valley
# Processing Record 7 of Set 1 | bud
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | arraial do cabo
# Processing Record 10 of Set 1 | samarai
# Processing Record 11 of Set 1 | ponta do sol
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | bintulu
# Processing Record 14 of Set 1 | verkhnyaya inta
# Processing Record 15 of Set 1 | harwich
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | yellowknife
# Processing Record 18 of Set 1 | ha tinh
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | sur
# Processing Record 21 of Set 1 | souillac
# Processing Record 22 of Set 1 | krasnoselkup
# Processing Record 23 of Set 1 | tubuala
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | port elizabeth
# Processing Record 26 of Set 1 | katsuura
# Processing Record 27 of Set 1 | tasiilaq
# Processing Record 28 of Set 1 | sioux lookout
# Processing Record 29 of Set 1 | mahebourg
# Processing Record 30 of Set 1 | stoyba
# City not found. Skipping...
# Processing Record 31 of Set 1 | acari
# Processing Record 32 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 1 | salinas
# Processing Record 34 of Set 1 | bosobolo
# Processing Record 35 of Set 1 | punta arenas
# Processing Record 36 of Set 1 | east london
# Processing Record 37 of Set 1 | avarua
# Processing Record 38 of Set 1 | skegness
# Processing Record 39 of Set 1 | new norfolk
# Processing Record 40 of Set 1 | vanimo
# Processing Record 41 of Set 1 | lavrentiya
# Processing Record 42 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 1 | busselton
# Processing Record 44 of Set 1 | puerto ayora
# Processing Record 45 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 1 | port alfred
# Processing Record 48 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 1 | laerdalsoyri
# Processing Record 50 of Set 1 | rikitea
# Processing Record 1 of Set 2 | atar
# Processing Record 2 of Set 2 | jingdezhen
# Processing Record 3 of Set 2 | castro
# Processing Record 4 of Set 2 | watertown
# Processing Record 5 of Set 2 | svetlyy
# Processing Record 6 of Set 2 | yomitan
# City not found. Skipping...
# Processing Record 7 of Set 2 | axim
# Processing Record 8 of Set 2 | kissidougou
# Processing Record 9 of Set 2 | lagoa
# Processing Record 10 of Set 2 | dikson
# Processing Record 11 of Set 2 | bad nauheim
# Processing Record 12 of Set 2 | gazojak
# Processing Record 13 of Set 2 | upernavik
# Processing Record 14 of Set 2 | yeppoon
# Processing Record 15 of Set 2 | qaanaaq
# Processing Record 16 of Set 2 | atuona
# Processing Record 17 of Set 2 | sirjan
# Processing Record 18 of Set 2 | butaritari
# Processing Record 19 of Set 2 | bluff
# Processing Record 20 of Set 2 | nhamunda
# Processing Record 21 of Set 2 | kadykchan
# City not found. Skipping...
# Processing Record 22 of Set 2 | puerto ayacucho
# Processing Record 23 of Set 2 | san cristobal
# Processing Record 24 of Set 2 | mount gambier
# Processing Record 25 of Set 2 | lebu
# Processing Record 26 of Set 2 | saint-andre-les-vergers
# Processing Record 27 of Set 2 | port hardy
# Processing Record 28 of Set 2 | hobart
# Processing Record 29 of Set 2 | bredasdorp
# Processing Record 30 of Set 2 | kenai
# Processing Record 31 of Set 2 | aklavik
# Processing Record 32 of Set 2 | cassilandia
# Processing Record 33 of Set 2 | cape town
# Processing Record 34 of Set 2 | asau
# Processing Record 35 of Set 2 | tezu
# Processing Record 36 of Set 2 | hermanus
# Processing Record 37 of Set 2 | kapaa
# Processing Record 38 of Set 2 | severo-kurilsk
# Processing Record 39 of Set 2 | ostrovnoy
# Processing Record 40 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 2 | itarema
# Processing Record 42 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 2 | san patricio
# Processing Record 44 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 2 | kaz
# Processing Record 46 of Set 2 | mahibadhoo
# Processing Record 47 of Set 2 | vestmanna
# Processing Record 48 of Set 2 | tiksi
# Processing Record 49 of Set 2 | jalpan
# Processing Record 50 of Set 2 | luderitz
# Processing Record 1 of Set 3 | cayenne
# Processing Record 2 of Set 3 | san carlos de bariloche
# Processing Record 3 of Set 3 | faro
# Processing Record 4 of Set 3 | port hedland
# Processing Record 5 of Set 3 | panuco
# Processing Record 6 of Set 3 | san quintin
# Processing Record 7 of Set 3 | torbay
# Processing Record 8 of Set 3 | ous
# Processing Record 9 of Set 3 | hilo
# Processing Record 10 of Set 3 | dzhebariki-khaya
# Processing Record 11 of Set 3 | sola
# Processing Record 12 of Set 3 | esperance
# Processing Record 13 of Set 3 | bubaque
# Processing Record 14 of Set 3 | hovd
# Processing Record 15 of Set 3 | riyadh
# Processing Record 16 of Set 3 | caibarien
# Processing Record 17 of Set 3 | carnarvon
# Processing Record 18 of Set 3 | rio branco
# Processing Record 19 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 3 | husavik
# Processing Record 21 of Set 3 | tolaga bay
# Processing Record 22 of Set 3 | eyl
# Processing Record 23 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 3 | alta floresta
# Processing Record 25 of Set 3 | eskisehir
# Processing Record 26 of Set 3 | jiuquan
# Processing Record 27 of Set 3 | haines junction
# Processing Record 28 of Set 3 | puerto escondido
# Processing Record 29 of Set 3 | hamilton
# Processing Record 30 of Set 3 | tomatlan
# Processing Record 31 of Set 3 | serowe
# Processing Record 32 of Set 3 | gunjur
# Processing Record 33 of Set 3 | bathsheba
# Processing Record 34 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 3 | flinders
# Processing Record 36 of Set 3 | saskylakh
# Processing Record 37 of Set 3 | charters towers
# Processing Record 38 of Set 3 | brae
# Processing Record 39 of Set 3 | hambantota
# Processing Record 40 of Set 3 | gimli
# Processing Record 41 of Set 3 | manthani
# Processing Record 42 of Set 3 | waddan
# Processing Record 43 of Set 3 | nikolskoye
# Processing Record 44 of Set 3 | uwayl
# City not found. Skipping...
# Processing Record 45 of Set 3 | chuy
# Processing Record 46 of Set 3 | lopsmarka
# Processing Record 47 of Set 3 | muros
# Processing Record 48 of Set 3 | taksimo
# Processing Record 49 of Set 3 | kodiak
# Processing Record 50 of Set 3 | hithadhoo
# Processing Record 1 of Set 4 | bandundu
# Processing Record 2 of Set 4 | ancud
# Processing Record 3 of Set 4 | jieshi
# Processing Record 4 of Set 4 | lorengau
# Processing Record 5 of Set 4 | vancouver
# Processing Record 6 of Set 4 | carballo
# Processing Record 7 of Set 4 | kaitangata
# Processing Record 8 of Set 4 | amapa
# Processing Record 9 of Set 4 | deputatskiy
# Processing Record 10 of Set 4 | sitka
# Processing Record 11 of Set 4 | klaksvik
# Processing Record 12 of Set 4 | coquimbo
# Processing Record 13 of Set 4 | fort myers beach
# Processing Record 14 of Set 4 | isangel
# Processing Record 15 of Set 4 | sao joao da barra
# Processing Record 16 of Set 4 | huarmey
# Processing Record 17 of Set 4 | tenenkou
# Processing Record 18 of Set 4 | puerto baquerizo moreno
# Processing Record 19 of Set 4 | bandarbeyla
# Processing Record 20 of Set 4 | fortuna
# Processing Record 21 of Set 4 | nha trang
# Processing Record 22 of Set 4 | nanortalik
# Processing Record 23 of Set 4 | provideniya
# Processing Record 24 of Set 4 | tuysarkan
# City not found. Skipping...
# Processing Record 25 of Set 4 | gornopravdinsk
# Processing Record 26 of Set 4 | nelson bay
# Processing Record 27 of Set 4 | kingisepp
# Processing Record 28 of Set 4 | barreirinha
# Processing Record 29 of Set 4 | constitucion
# Processing Record 30 of Set 4 | ungheni
# Processing Record 31 of Set 4 | bocas del toro
# Processing Record 32 of Set 4 | tommot
# Processing Record 33 of Set 4 | moose factory
# Processing Record 34 of Set 4 | saint-augustin
# Processing Record 35 of Set 4 | daru
# Processing Record 36 of Set 4 | touba
# Processing Record 37 of Set 4 | pergamino
# Processing Record 38 of Set 4 | ahuimanu
# Processing Record 39 of Set 4 | cankuzo
# Processing Record 40 of Set 4 | makung
# City not found. Skipping...
# Processing Record 41 of Set 4 | bambous virieux
# Processing Record 42 of Set 4 | guerrero
# Processing Record 43 of Set 4 | barrow
# Processing Record 44 of Set 4 | flin flon
# Processing Record 45 of Set 4 | yar-sale
# Processing Record 46 of Set 4 | tuktoyaktuk
# Processing Record 47 of Set 4 | ahipara
# Processing Record 48 of Set 4 | komsomolskiy
# Processing Record 49 of Set 4 | coihaique
# Processing Record 50 of Set 4 | westport
# Processing Record 1 of Set 5 | kang
# Processing Record 2 of Set 5 | augusto correa
# Processing Record 3 of Set 5 | ribeira grande
# Processing Record 4 of Set 5 | mabaruma
# Processing Record 5 of Set 5 | krasnyy yar
# Processing Record 6 of Set 5 | honiara
# Processing Record 7 of Set 5 | rio grande
# Processing Record 8 of Set 5 | tromso
# Processing Record 9 of Set 5 | ambovombe
# Processing Record 10 of Set 5 | kodinsk
# Processing Record 11 of Set 5 | mehamn
# Processing Record 12 of Set 5 | iwanai
# Processing Record 13 of Set 5 | dubai
# Processing Record 14 of Set 5 | anisoc
# Processing Record 15 of Set 5 | noumea
# Processing Record 16 of Set 5 | jumla
# Processing Record 17 of Set 5 | la palma
# Processing Record 18 of Set 5 | saldanha
# Processing Record 19 of Set 5 | san jose
# Processing Record 20 of Set 5 | mongo
# Processing Record 21 of Set 5 | cap-aux-meules
# Processing Record 22 of Set 5 | terrace
# Processing Record 23 of Set 5 | pozo colorado
# Processing Record 24 of Set 5 | vostok
# Processing Record 25 of Set 5 | bandar-e anzali
# Processing Record 26 of Set 5 | saint-philippe
# Processing Record 27 of Set 5 | nicoya
# Processing Record 28 of Set 5 | salinopolis
# Processing Record 29 of Set 5 | kavaratti
# Processing Record 30 of Set 5 | lichinga
# Processing Record 31 of Set 5 | port lincoln
# Processing Record 32 of Set 5 | saint george
# Processing Record 33 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 5 | tecoanapa
# Processing Record 35 of Set 5 | hasaki
# Processing Record 36 of Set 5 | sao bernardo
# Processing Record 37 of Set 5 | caravelas
# Processing Record 38 of Set 5 | pio ix
# Processing Record 39 of Set 5 | mar del plata
# Processing Record 40 of Set 5 | sao filipe
# Processing Record 41 of Set 5 | tura
# Processing Record 42 of Set 5 | lazne bohdanec
# Processing Record 43 of Set 5 | kruisfontein
# Processing Record 44 of Set 5 | vardo
# Processing Record 45 of Set 5 | mecca
# Processing Record 46 of Set 5 | vysokogornyy
# Processing Record 47 of Set 5 | roebourne
# Processing Record 48 of Set 5 | tuatapere
# Processing Record 49 of Set 5 | beringovskiy
# Processing Record 50 of Set 5 | vicksburg
# Processing Record 1 of Set 6 | rafaela
# Processing Record 2 of Set 6 | thompson
# Processing Record 3 of Set 6 | tazovskiy
# Processing Record 4 of Set 6 | portland
# Processing Record 5 of Set 6 | paranga
# Processing Record 6 of Set 6 | hami
# Processing Record 7 of Set 6 | havoysund
# Processing Record 8 of Set 6 | comodoro rivadavia
# Processing Record 9 of Set 6 | saalfelden
# City not found. Skipping...
# Processing Record 10 of Set 6 | bima
# Processing Record 11 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 6 | pilar
# Processing Record 13 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 14 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 6 | sakata
# Processing Record 16 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 6 | borlange
# City not found. Skipping...
# Processing Record 18 of Set 6 | bang rakam
# Processing Record 19 of Set 6 | cortez
# Processing Record 20 of Set 6 | valparaiso
# Processing Record 21 of Set 6 | zhigansk
# Processing Record 22 of Set 6 | gavle
# Processing Record 23 of Set 6 | naze
# Processing Record 24 of Set 6 | kolyvan
# Processing Record 25 of Set 6 | hirado
# Processing Record 26 of Set 6 | carutapera
# Processing Record 27 of Set 6 | vila
# Processing Record 28 of Set 6 | skjervoy
# Processing Record 29 of Set 6 | odweyne
# Processing Record 30 of Set 6 | georgetown
# Processing Record 31 of Set 6 | lujan
# Processing Record 32 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 33 of Set 6 | pangody
# Processing Record 34 of Set 6 | padang
# Processing Record 35 of Set 6 | yangambi
# Processing Record 36 of Set 6 | burnie
# Processing Record 37 of Set 6 | nikel
# Processing Record 38 of Set 6 | soyo
# Processing Record 39 of Set 6 | heishan
# Processing Record 40 of Set 6 | birin
# Processing Record 41 of Set 6 | lata
# Processing Record 42 of Set 6 | pacific grove
# Processing Record 43 of Set 6 | khatanga
# Processing Record 44 of Set 6 | tyret pervaya
# Processing Record 45 of Set 6 | kyzyl-suu
# Processing Record 46 of Set 6 | mackay
# Processing Record 47 of Set 6 | natal
# Processing Record 48 of Set 6 | port blair
# Processing Record 49 of Set 6 | alyangula
# Processing Record 50 of Set 6 | victoria
# Processing Record 1 of Set 7 | cap malheureux
# Processing Record 2 of Set 7 | gladstone
# Processing Record 3 of Set 7 | banjarmasin
# Processing Record 4 of Set 7 | byron bay
# Processing Record 5 of Set 7 | tilisca
# Processing Record 6 of Set 7 | namibe
# Processing Record 7 of Set 7 | loanda
# Processing Record 8 of Set 7 | jizan
# Processing Record 9 of Set 7 | komsomolets
# Processing Record 10 of Set 7 | mindelo
# Processing Record 11 of Set 7 | dabakala
# Processing Record 12 of Set 7 | batagay
# Processing Record 13 of Set 7 | narsaq
# Processing Record 14 of Set 7 | rawlins
# Processing Record 15 of Set 7 | buba
# Processing Record 16 of Set 7 | waingapu
# Processing Record 17 of Set 7 | tongren
# Processing Record 18 of Set 7 | batemans bay
# Processing Record 19 of Set 7 | bilibino
# Processing Record 20 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 7 | irbeyskoye
# Processing Record 22 of Set 7 | olinda
# Processing Record 23 of Set 7 | veseloyarsk
# Processing Record 24 of Set 7 | namatanai
# Processing Record 25 of Set 7 | richards bay
# Processing Record 26 of Set 7 | kutum
# Processing Record 27 of Set 7 | harper
# Processing Record 28 of Set 7 | srandakan
# Processing Record 29 of Set 7 | vila franca do campo
# Processing Record 30 of Set 7 | talnakh
# Processing Record 31 of Set 7 | korla
# Processing Record 32 of Set 7 | inta
# Processing Record 33 of Set 7 | puerto madryn
# Processing Record 34 of Set 7 | pevek
# Processing Record 35 of Set 7 | longyearbyen
# Processing Record 36 of Set 7 | methoni
# Processing Record 37 of Set 7 | bababe
# City not found. Skipping...
# Processing Record 38 of Set 7 | casa nova
# Processing Record 39 of Set 7 | toyooka
# Processing Record 40 of Set 7 | dingle
# Processing Record 41 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 42 of Set 7 | banmo
# City not found. Skipping...
# Processing Record 43 of Set 7 | hervey bay
# Processing Record 44 of Set 7 | muli
# Processing Record 45 of Set 7 | calama
# Processing Record 46 of Set 7 | gigmoto
# Processing Record 47 of Set 7 | codajas
# Processing Record 48 of Set 7 | norman wells
# Processing Record 49 of Set 7 | leningradskiy
# Processing Record 50 of Set 7 | faya
# Processing Record 1 of Set 8 | sambava
# Processing Record 2 of Set 8 | marsh harbour
# Processing Record 3 of Set 8 | tessalit
# Processing Record 4 of Set 8 | tonantins
# Processing Record 5 of Set 8 | nova odesa
# Processing Record 6 of Set 8 | la suiza
# Processing Record 7 of Set 8 | kahului
# Processing Record 8 of Set 8 | la libertad
# Processing Record 9 of Set 8 | quelimane
# Processing Record 10 of Set 8 | kyabram
# Processing Record 11 of Set 8 | tabas
# Processing Record 12 of Set 8 | boyolangu
# Processing Record 13 of Set 8 | ambilobe
# Processing Record 14 of Set 8 | labuhan
# Processing Record 15 of Set 8 | nara
# Processing Record 16 of Set 8 | ilulissat
# Processing Record 17 of Set 8 | prado
# Processing Record 18 of Set 8 | srednekolymsk
# Processing Record 19 of Set 8 | eldikan
# City not found. Skipping...
# Processing Record 20 of Set 8 | alofi
# Processing Record 21 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 22 of Set 8 | iqaluit
# Processing Record 23 of Set 8 | kathu
# Processing Record 24 of Set 8 | grong
# Processing Record 25 of Set 8 | coos bay
# Processing Record 26 of Set 8 | poum
# Processing Record 27 of Set 8 | loandjili
# Processing Record 28 of Set 8 | kushmurun
# Processing Record 29 of Set 8 | tevaitoa
# Processing Record 30 of Set 8 | hazorasp
# Processing Record 31 of Set 8 | necochea
# Processing Record 32 of Set 8 | baloda
# Processing Record 33 of Set 8 | outjo
# Processing Record 34 of Set 8 | montorio al vomano
# Processing Record 35 of Set 8 | dudinka
# Processing Record 36 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 37 of Set 8 | ixtapa
# Processing Record 38 of Set 8 | itoman
# Processing Record 39 of Set 8 | kyaiklat
# Processing Record 40 of Set 8 | olafsvik
# Processing Record 41 of Set 8 | djibo
# Processing Record 42 of Set 8 | matay
# Processing Record 43 of Set 8 | asfi
# Processing Record 44 of Set 8 | ngunguru
# Processing Record 45 of Set 8 | jilib
# Processing Record 46 of Set 8 | chokurdakh
# Processing Record 47 of Set 8 | rantepao
# Processing Record 48 of Set 8 | akyab
# Processing Record 49 of Set 8 | cervo
# Processing Record 50 of Set 8 | arcata
# Processing Record 1 of Set 9 | russell
# Processing Record 2 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 9 | otane
# Processing Record 4 of Set 9 | del rio
# Processing Record 5 of Set 9 | trapani
# Processing Record 6 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 7 of Set 9 | nizwa
# Processing Record 8 of Set 9 | saint-pierre
# Processing Record 9 of Set 9 | de-kastri
# Processing Record 10 of Set 9 | santa lucia
# Processing Record 11 of Set 9 | rancho palos verdes
# Processing Record 12 of Set 9 | laguna
# Processing Record 13 of Set 9 | stornoway
# Processing Record 14 of Set 9 | brooks
# Processing Record 15 of Set 9 | arona
# Processing Record 16 of Set 9 | sroda wielkopolska
# Processing Record 17 of Set 9 | cherskiy
# Processing Record 18 of Set 9 | sandalfoot cove
# Processing Record 19 of Set 9 | chimore
# Processing Record 20 of Set 9 | cockburn town
# Processing Record 21 of Set 9 | chandler
# Processing Record 22 of Set 9 | usinsk
# Processing Record 23 of Set 9 | piacabucu
# Processing Record 24 of Set 9 | pitsunda
# Processing Record 25 of Set 9 | ulaanbaatar
# Processing Record 26 of Set 9 | karratha
# Processing Record 27 of Set 9 | sisimiut
# Processing Record 28 of Set 9 | nioro
# Processing Record 29 of Set 9 | cabo san lucas
# Processing Record 30 of Set 9 | lompoc
# Processing Record 31 of Set 9 | balgazyn
# Processing Record 32 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 33 of Set 9 | waitara
# Processing Record 34 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 35 of Set 9 | vilcun
# Processing Record 36 of Set 9 | acapulco
# Processing Record 37 of Set 9 | mina
# Processing Record 38 of Set 9 | nuevo progreso
# Processing Record 39 of Set 9 | nhulunbuy
# Processing Record 40 of Set 9 | champerico
# Processing Record 41 of Set 9 | emerald
# Processing Record 42 of Set 9 | okoneshnikovo
# Processing Record 43 of Set 9 | shuya
# Processing Record 44 of Set 9 | koratla
# Processing Record 45 of Set 9 | katherine
# Processing Record 46 of Set 9 | bela
# Processing Record 47 of Set 9 | warmbad
# Processing Record 48 of Set 9 | micheweni
# Processing Record 49 of Set 9 | dukat
# Processing Record 50 of Set 9 | tombouctou
# Processing Record 1 of Set 10 | nago
# Processing Record 2 of Set 10 | george town
# Processing Record 3 of Set 10 | key largo
# Processing Record 4 of Set 10 | havre-saint-pierre
# Processing Record 5 of Set 10 | chapleau
# Processing Record 6 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 10 | santiago del estero
# Processing Record 8 of Set 10 | barcelos
# Processing Record 9 of Set 10 | brod
# Processing Record 10 of Set 10 | kidal
# Processing Record 11 of Set 10 | vicuna
# Processing Record 12 of Set 10 | saint anthony
# Processing Record 13 of Set 10 | anadyr
# Processing Record 14 of Set 10 | arman
# Processing Record 15 of Set 10 | scottsburgh
# City not found. Skipping...
# Processing Record 16 of Set 10 | sedelnikovo
# City not found. Skipping...
# Processing Record 17 of Set 10 | abha
# Processing Record 18 of Set 10 | margate
# Processing Record 19 of Set 10 | vilhena
# Processing Record 20 of Set 10 | thinadhoo
# Processing Record 21 of Set 10 | la rioja
# Processing Record 22 of Set 10 | beloha
# Processing Record 23 of Set 10 | airai
# Processing Record 24 of Set 10 | nanakuli
# Processing Record 25 of Set 10 | codrington
# Processing Record 26 of Set 10 | inuvik
# Processing Record 27 of Set 10 | katima mulilo
# Processing Record 28 of Set 10 | payo
# Processing Record 29 of Set 10 | nome
# Processing Record 30 of Set 10 | maymyo
# Processing Record 31 of Set 10 | ulladulla
# Processing Record 32 of Set 10 | grande-riviere
# City not found. Skipping...
# Processing Record 33 of Set 10 | gamba
# Processing Record 34 of Set 10 | praia da vitoria
# Processing Record 35 of Set 10 | belmonte
# Processing Record 36 of Set 10 | wasilla
# Processing Record 37 of Set 10 | taoudenni
# Processing Record 38 of Set 10 | bemidji
# Processing Record 39 of Set 10 | ankazoabo
# Processing Record 40 of Set 10 | buraydah
# Processing Record 41 of Set 10 | grand-lahou
# Processing Record 42 of Set 10 | lubawa
# Processing Record 43 of Set 10 | banda aceh
# Processing Record 44 of Set 10 | baruun-urt
# Processing Record 45 of Set 10 | astana
# Processing Record 46 of Set 10 | cidreira
# Processing Record 47 of Set 10 | marienburg
# Processing Record 48 of Set 10 | angangxi
# City not found. Skipping...
# Processing Record 49 of Set 10 | whitianga
# Processing Record 50 of Set 10 | bonthe
# Processing Record 1 of Set 11 | ndele
# Processing Record 2 of Set 11 | barra
# Processing Record 3 of Set 11 | burla
# Processing Record 4 of Set 11 | avera
# Processing Record 5 of Set 11 | da lat
# Processing Record 6 of Set 11 | faanui
# Processing Record 7 of Set 11 | sangod
# Processing Record 8 of Set 11 | geraldton
# Processing Record 9 of Set 11 | emirdag
# Processing Record 10 of Set 11 | issenye
# Processing Record 11 of Set 11 | harstad
# Processing Record 12 of Set 11 | ciudad real
# Processing Record 13 of Set 11 | havelock
# Processing Record 14 of Set 11 | tautira
# Processing Record 15 of Set 11 | janakkala
# Processing Record 16 of Set 11 | rocha
# Processing Record 17 of Set 11 | hofn
# Processing Record 18 of Set 11 | pierre
# Processing Record 19 of Set 11 | mullaitivu
# City not found. Skipping...
# Processing Record 20 of Set 11 | neiafu
# Processing Record 21 of Set 11 | fort nelson
# Processing Record 22 of Set 11 | gambela
# Processing Record 23 of Set 11 | khorixas
# Processing Record 24 of Set 11 | qaqortoq
# Processing Record 25 of Set 11 | kerteh
# City not found. Skipping...
# Processing Record 26 of Set 11 | candawaga
# City not found. Skipping...
# Processing Record 27 of Set 11 | adrar
# Processing Record 28 of Set 11 | vieste
# Processing Record 29 of Set 11 | bac lieu
# Processing Record 30 of Set 11 | vangaindrano
# Processing Record 31 of Set 11 | suda
# Processing Record 32 of Set 11 | ust-kuyga
# Processing Record 33 of Set 11 | nizhniy kuranakh
# Processing Record 34 of Set 11 | gold coast
# Processing Record 35 of Set 11 | fairbanks
# Processing Record 36 of Set 11 | novo aripuana
# Processing Record 37 of Set 11 | bam
# Processing Record 38 of Set 11 | madimba
# Processing Record 39 of Set 11 | banikoara
# Processing Record 40 of Set 11 | beinamar
# Processing Record 41 of Set 11 | kalangala
# Processing Record 42 of Set 11 | sangar
# Processing Record 43 of Set 11 | hakui
# Processing Record 44 of Set 11 | lagos
# Processing Record 45 of Set 11 | jalu
# Processing Record 46 of Set 11 | paranhos
# Processing Record 47 of Set 11 | baleshwar
# Processing Record 48 of Set 11 | jijiga
# Processing Record 49 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 11 | effingham
# Processing Record 1 of Set 12 | simbahan
# Processing Record 2 of Set 12 | sampit
# Processing Record 3 of Set 12 | pisco
# Processing Record 4 of Set 12 | ystad
# Processing Record 5 of Set 12 | grindavik
# Processing Record 6 of Set 12 | laredo
# Processing Record 7 of Set 12 | lasa
# Processing Record 8 of Set 12 | takoradi
# Processing Record 9 of Set 12 | sorland
# Processing Record 10 of Set 12 | trzebiatow
# Processing Record 11 of Set 12 | brigantine
# Processing Record 12 of Set 12 | mount isa
# Processing Record 13 of Set 12 | bahia blanca
# Processing Record 14 of Set 12 | trinidad
# Processing Record 15 of Set 12 | gondanglegi
# Processing Record 16 of Set 12 | katha
# City not found. Skipping...
# Processing Record 17 of Set 12 | yumen
# Processing Record 18 of Set 12 | hualmay
# Processing Record 19 of Set 12 | shashi
# Processing Record 20 of Set 12 | northam
# Processing Record 21 of Set 12 | kavieng
# Processing Record 22 of Set 12 | zemio
# Processing Record 23 of Set 12 | porto belo
# Processing Record 24 of Set 12 | tigil
# Processing Record 25 of Set 12 | barstow
# Processing Record 26 of Set 12 | talcahuano
# Processing Record 27 of Set 12 | coahuayana
# Processing Record 28 of Set 12 | djenne
# Processing Record 29 of Set 12 | shache
# Processing Record 30 of Set 12 | genhe
# Processing Record 31 of Set 12 | meulaboh
# Processing Record 32 of Set 12 | hornepayne
# Processing Record 33 of Set 12 | mauganj
# Processing Record 34 of Set 12 | kismayo
# Processing Record 35 of Set 12 | yatou
# Processing Record 36 of Set 12 | alekseyevskoye
# Processing Record 37 of Set 12 | lashio
# Processing Record 38 of Set 12 | funchal
# Processing Record 39 of Set 12 | porvoo
# Processing Record 40 of Set 12 | camacha
# Processing Record 41 of Set 12 | orange cove
# Processing Record 42 of Set 12 | filingue
# Processing Record 43 of Set 12 | xining
# Processing Record 44 of Set 12 | lucapa
# Processing Record 45 of Set 12 | saint-francois
# Processing Record 46 of Set 12 | capoeiras
# Processing Record 47 of Set 12 | manitouwadge
# Processing Record 48 of Set 12 | ikongo
# Processing Record 49 of Set 12 | stavern
# Processing Record 50 of Set 12 | youhao
# Processing Record 1 of Set 13 | marystown
# Processing Record 2 of Set 13 | buala
# Processing Record 3 of Set 13 | fare
# Processing Record 4 of Set 13 | buncrana
# Processing Record 5 of Set 13 | paamiut
# Processing Record 6 of Set 13 | opuwo
# Processing Record 7 of Set 13 | zlatoustovsk
# City not found. Skipping...
# Processing Record 8 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 9 of Set 13 | manado
# Processing Record 10 of Set 13 | artyom
# Processing Record 11 of Set 13 | keflavik
# Processing Record 12 of Set 13 | sao jose da coroa grande
# Processing Record 13 of Set 13 | oktyabrskoye
# Processing Record 14 of Set 13 | college
# Processing Record 15 of Set 13 | alekseyevskaya
# Processing Record 16 of Set 13 | santa cruz
# Processing Record 17 of Set 13 | quatre cocos
# Processing Record 18 of Set 13 | jinka
# Processing Record 19 of Set 13 | deniliquin
# Processing Record 20 of Set 13 | illapel
# Processing Record 21 of Set 13 | camopi
# Processing Record 22 of Set 13 | guinabsan
# Processing Record 23 of Set 13 | new port richey
# Processing Record 24 of Set 13 | guajara-mirim
# City not found. Skipping...
# Processing Record 25 of Set 13 | la ronge
# Processing Record 26 of Set 13 | muriti
# Processing Record 27 of Set 13 | kieta
# Processing Record 28 of Set 13 | belebey
# Processing Record 29 of Set 13 | pemangkat
# Processing Record 30 of Set 13 | ozuluama
# Processing Record 31 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 32 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 33 of Set 13 | svetlogorsk
# Processing Record 34 of Set 13 | sakaiminato
# Processing Record 35 of Set 13 | preston
# Processing Record 36 of Set 13 | aleksandrovsk-sakhalinskiy
# Processing Record 37 of Set 13 | henties bay
# Processing Record 38 of Set 13 | little current
# Processing Record 39 of Set 13 | seymchan
# Processing Record 40 of Set 13 | haileybury
# Processing Record 41 of Set 13 | ginda
# Processing Record 42 of Set 13 | morrinhos
# Processing Record 43 of Set 13 | ewa beach
# Processing Record 44 of Set 13 | prieska
# Processing Record 45 of Set 13 | kimberley
# Processing Record 46 of Set 13 | aswan
# Processing Record 47 of Set 13 | esna
# Processing Record 48 of Set 13 | diego de almagro
# Processing Record 49 of Set 13 | fonte boa
# Processing Record 50 of Set 13 | shelburne
# Processing Record 1 of Set 14 | armidale
# Processing Record 2 of Set 14 | porto novo
# Processing Record 3 of Set 14 | aykhal
# Processing Record 4 of Set 14 | sooke
# Processing Record 5 of Set 14 | marihatag
# Processing Record 6 of Set 14 | candelaria
# Processing Record 7 of Set 14 | villa carlos paz
# Processing Record 8 of Set 14 | morant bay
# Processing Record 9 of Set 14 | bekessamson
# Processing Record 10 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 14 | grand gaube
# Processing Record 12 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 14 | mata
# Processing Record 14 of Set 14 | biloela
# Processing Record 15 of Set 14 | talaya
# Processing Record 16 of Set 14 | salym
# Processing Record 17 of Set 14 | shimoda
# Processing Record 18 of Set 14 | camapua
# Processing Record 19 of Set 14 | romitan
# Processing Record 20 of Set 14 | medina del campo
# Processing Record 21 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 22 of Set 14 | bermeo
# Processing Record 23 of Set 14 | buon me thuot
# City not found. Skipping...
# Processing Record 24 of Set 14 | kysyl-syr
# Processing Record 25 of Set 14 | agua verde
# Processing Record 26 of Set 14 | hokitika
# Processing Record 27 of Set 14 | malanje
# Processing Record 28 of Set 14 | blagoyevo
# Processing Record 29 of Set 14 | katobu
# Processing Record 30 of Set 14 | san felipe
# Processing Record 31 of Set 14 | phalaborwa
# Processing Record 32 of Set 14 | colares
# Processing Record 33 of Set 14 | mandan
# Processing Record 34 of Set 14 | chokwe
# Processing Record 35 of Set 14 | adeje
# Processing Record 36 of Set 14 | kovernino
# Processing Record 37 of Set 14 | novokruchininskiy
# Processing Record 38 of Set 14 | beira
# Processing Record 39 of Set 14 | port-gentil
# Processing Record 40 of Set 14 | acarau
# Processing Record 41 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 42 of Set 14 | linfen
# Processing Record 43 of Set 14 | marzuq
# Processing Record 44 of Set 14 | santiago
# Processing Record 45 of Set 14 | alipur chatha
# Processing Record 46 of Set 14 | cabedelo
# Processing Record 47 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 48 of Set 14 | campbell river
# Processing Record 49 of Set 14 | szigetvar
# Processing Record 50 of Set 14 | ilabaya
# Processing Record 1 of Set 15 | jasper
# Processing Record 2 of Set 15 | joao pinheiro
# Processing Record 3 of Set 15 | mareeba
# Processing Record 4 of Set 15 | touros
# Processing Record 5 of Set 15 | burica
# City not found. Skipping...
# Processing Record 6 of Set 15 | mandalgovi
# Processing Record 7 of Set 15 | yangjiang
# Processing Record 8 of Set 15 | ishigaki
# Processing Record 9 of Set 15 | vestmannaeyjar
# Processing Record 10 of Set 15 | boguchany
# Processing Record 11 of Set 15 | semporna
# Processing Record 12 of Set 15 | manicore
# Processing Record 13 of Set 15 | palana
# Processing Record 14 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 15 of Set 15 | kashi
# Processing Record 16 of Set 15 | arinos
# Processing Record 17 of Set 15 | panama city
# Processing Record 18 of Set 15 | izumo
# Processing Record 19 of Set 15 | santa isabel do rio negro
# Processing Record 20 of Set 15 | san andres
# Processing Record 21 of Set 15 | pimentel
# Processing Record 22 of Set 15 | warrnambool
# Processing Record 23 of Set 15 | aberdeen
# Processing Record 24 of Set 15 | honningsvag
# Processing Record 25 of Set 15 | shebunino
# Processing Record 26 of Set 15 | camana
# Processing Record 27 of Set 15 | kupang
# Processing Record 28 of Set 15 | xixiang
# Processing Record 29 of Set 15 | san angelo
# Processing Record 30 of Set 15 | guerrero negro
# Processing Record 31 of Set 15 | pedernales
# Processing Record 32 of Set 15 | nueva helvecia
# Processing Record 33 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 34 of Set 15 | high level
# Processing Record 35 of Set 15 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 36 of Set 15 | surgut
# Processing Record 37 of Set 15 | santa luzia
# Processing Record 38 of Set 15 | el faiyum
# City not found. Skipping...
# Processing Record 39 of Set 15 | kant
# Processing Record 40 of Set 15 | sabancuy
# Processing Record 41 of Set 15 | escarcega
# Processing Record 42 of Set 15 | vallenar
# Processing Record 43 of Set 15 | moerai
# Processing Record 44 of Set 15 | greenwood
# Processing Record 45 of Set 15 | tupelo
# Processing Record 46 of Set 15 | samokov
# Processing Record 47 of Set 15 | sarangani
# Processing Record 48 of Set 15 | nantucket
# Processing Record 49 of Set 15 | southbridge
# Processing Record 50 of Set 15 | rosarito
# Processing Record 1 of Set 16 | prince rupert
# Processing Record 2 of Set 16 | coromandel
# Processing Record 3 of Set 16 | sorkjosen
# Processing Record 4 of Set 16 | teguldet
# Processing Record 5 of Set 16 | te anau
# Processing Record 6 of Set 16 | dera bugti
# Processing Record 7 of Set 16 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 8 of Set 16 | sitia
# Processing Record 9 of Set 16 | dharchula
# Processing Record 10 of Set 16 | zhangye
# Processing Record 11 of Set 16 | hedaru
# Processing Record 12 of Set 16 | pathein
# Processing Record 13 of Set 16 | moindou
# Processing Record 14 of Set 16 | sorong
# Processing Record 15 of Set 16 | thongwa
# Processing Record 16 of Set 16 | kamsack
# Processing Record 17 of Set 16 | ilhabela
# Processing Record 18 of Set 16 | ugoofaaru
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 705

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Clyde River  70.4692  -68.5914     -7.37        84         100
# 1         Majenang  -7.2975  108.7642     76.91        93         100
# 2         Bengkulu  -3.8004  102.2655     75.76        90         100
# 3           Bethel  41.3712  -73.4140     23.56        51           0
# 4           Valley  45.1277 -116.1262     24.60        74          17
# 5              Bud  39.4470  -86.1758     20.86        56           0
# 6            Vaini -21.2000 -175.2000     87.96        74          20
# 7  Arraial Do Cabo -22.9661  -42.0278     78.76        73           0
# 8          Samarai -10.6167  150.6667     84.96        71         100
# 9     Ponta Do Sol  32.6667  -17.1000     60.71        67          79
#
#    Wind Speed Country Current Description
# 0       28.77      CA                snow
# 1        0.74      ID     overcast clouds
# 2        3.94      ID     overcast clouds
# 3        9.22      US           clear sky
# 4        1.36      US          few clouds
# 5        2.30      US           clear sky
# 6        6.91      TO          few clouds
# 7       13.80      BR           clear sky
# 8        4.25      PG     overcast clouds
# 9        6.89      PT       broken clouds

# %%
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']

# %%
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Clyde River      CA  70.4692  -68.5914     -7.37        84         100
# 1         Majenang      ID  -7.2975  108.7642     76.91        93         100
# 2         Bengkulu      ID  -3.8004  102.2655     75.76        90         100
# 3           Bethel      US  41.3712  -73.4140     23.56        51           0
# 4           Valley      US  45.1277 -116.1262     24.60        74          17
# 5              Bud      US  39.4470  -86.1758     20.86        56           0
# 6            Vaini      TO -21.2000 -175.2000     87.96        74          20
# 7  Arraial Do Cabo      BR -22.9661  -42.0278     78.76        73           0
# 8          Samarai      PG -10.6167  150.6667     84.96        71         100
# 9     Ponta Do Sol      PT  32.6667  -17.1000     60.71        67          79
#
#    Wind Speed Current Description
# 0       28.77                snow
# 1        0.74     overcast clouds
# 2        3.94     overcast clouds
# 3        9.22           clear sky
# 4        1.36          few clouds
# 5        2.30           clear sky
# 6        6.91          few clouds
# 7       13.80           clear sky
# 8        4.25     overcast clouds
# 9        6.89       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
